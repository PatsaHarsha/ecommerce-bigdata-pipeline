# %% [markdown]
# # Layer 1: Setup & Data Loading
#
# Welcome to the Real-Time E-Commerce Pipeline! In this notebook, we preview the 2019 eCommerce behavior data from Kaggle.

# %%
import pandas as pd

# Note: This is a preview of the massive 20M row dataset
df_preview = pd.read_csv("../data/raw/2019-Oct.csv", nrows=10)
display(df_preview)
